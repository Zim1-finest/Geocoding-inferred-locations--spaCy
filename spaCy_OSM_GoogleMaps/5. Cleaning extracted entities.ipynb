# %% [markdown]
# # Cleaning extracted entities

# %%
# Import libriaries 
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
# from util import getCursor
from IPython.display import display, HTML # import display from Ipython.display instead of IPython.core.display
import base64

# %%
# Define display limits
pd.options.display.max_colwidth = 400
pd.set_option("display.max_rows", None,)

# %matplotlib inline  
# %load_ext autoreload
# %autoreload 2
display(HTML("<style>.container { width:98% !important; }</style>"))
# Out:
# <style>.container { width:98% !important; }</style>

# %%
df = pd.read_csv('data//analysis_data//keyword+temp_filtered_posts.csv')
df.shape

# %%
df.columns

# %%
df =df.drop(columns =['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1.1','Unnamed: 4'])

# %%
df.head(2)

# %%
# Count distinct by source
df.groupby(['source']).size().sort_values(ascending=False)

# %%
# replace all NaN with empty string
df = df.replace(np.nan, '', regex=True)
df.head()

# %%
# Data cleaning: Remove square brakets from entities
df['GPE'] =  df['GPE'].apply(lambda x: x.replace('[','').replace(']',''))
df['FAC'] =  df['FAC'].apply(lambda x: x.replace('[','').replace(']',''))
df['ORG'] =  df['ORG'].apply(lambda x: x.replace('[','').replace(']',''))
df['LOC'] =  df['LOC'].apply(lambda x: x.replace('[','').replace(']',''))
df['TE'] =  df['TE'].apply(lambda x: x.replace('[','').replace(']',''))
df.head(2)

# %%
# Extracting rows with TE
df_TE = df[(df['TE'] != '')]
df_TE.shape

# %%
# Count distinct by source
df_TE.groupby(['source']).size().sort_values(ascending=False)

# %%
df_TE[['en_text','TE']].head(50)

# %%
# Droping rows without location entity extracted
# Only drops rows where all conditions are met that is all four entities are equal to zero

index_names = df[(df['GPE']== '') & (df['FAC']== '') & (df['ORG']== '') & (df['LOC']== '')].index
df.drop(index_names, inplace = True)
df.shape

# %%
# Count distinct by source for only posts with location extracted
df.groupby(['source']).size().sort_values(ascending=False)

# %%
# Extracting rows with TE after dropping rows without location
df_TE = df[(df['TE'] != '')]
df_TE.shape

# %%
#df.to_csv('data//analysis_data//all_locations_extracted.csv')

# %% [markdown]
# ## Clean location entities

# %%
# Load dataset after keyword filtering and Temporal Information matching
df = pd.read_csv('data//analysis_data//keyword+temp_filtered_posts_final.csv')
df.shape

# %%
# replace all NaN with empty string
df = df.replace(np.nan, '', regex=True)
df.head()

# %%
print("Number of unique values:")
print("\n GPE =", df['GPE'].nunique(), "\n ORG =", df['ORG'].nunique(), "\n LOC =", df['LOC'].nunique(), "\n FAC =", df['FAC'].nunique())

# %%
# Remove hashtag signs on extracted locations
df['GPE'] = df['GPE'].str.replace('#','')
df['LOC'] = df['LOC'].str.replace('#','')
df['FAC'] = df['FAC'].str.replace('#','')
df['ORG'] = df['ORG'].str.replace('#','')

# %%
# Remove @ signs from extracted locations
df['GPE'] = df['GPE'].str.replace('@','')
df['LOC'] = df['LOC'].str.replace('@','')
df['FAC'] = df['FAC'].str.replace('@','')
df['ORG'] = df['ORG'].str.replace('@','')

# %%
# Add space when case changes 
df['GPE'] = df['GPE'].str.replace(r'([a-z](?=[A-Z])|[A-Z](?=[A-Z][a-z]))', r'\1 ').str.strip()
df['LOC'] = df['LOC'].str.replace(r'([a-z](?=[A-Z])|[A-Z](?=[A-Z][a-z]))', r'\1 ').str.strip()
df['FAC'] = df['FAC'].str.replace(r'([a-z](?=[A-Z])|[A-Z](?=[A-Z][a-z]))', r'\1 ').str.strip()
df['ORG'] = df['ORG'].str.replace(r'([a-z](?=[A-Z])|[A-Z](?=[A-Z][a-z]))', r'\1 ').str.strip()
df['LOC'].unique()

# %%
df[['GPE','FAC','LOC','ORG']].head(30)

# %%
# Counting comma separated entities
df['#LOC'] = df['LOC'].str.count(',')
df['#GPE'] = df['GPE'].str.count(',')
df['#ORG'] = df['ORG'].str.count(',')
df['#FAC'] = df['FAC'].str.count(',')
df[['GPE','#GPE']].head(10)

# %%
# Remove spaces between entities to generate unique entities
df['GPE'] = df['GPE'].str.replace(" ", "")
df['FAC'] = df['FAC'].str.replace(" ", "")
df['LOC'] = df['LOC'].str.replace(" ", "")
df['ORG'] = df['ORG'].str.replace(" ", "")

# %%
# Add space when case changes 
df['GPE'] = df['GPE'].str.replace(r'([a-z](?=[A-Z])|[A-Z](?=[A-Z][a-z]))', r'\1 ').str.strip()
df['LOC'] = df['LOC'].str.replace(r'([a-z](?=[A-Z])|[A-Z](?=[A-Z][a-z]))', r'\1 ').str.strip()
df['FAC'] = df['FAC'].str.replace(r'([a-z](?=[A-Z])|[A-Z](?=[A-Z][a-z]))', r'\1 ').str.strip()
df['ORG'] = df['ORG'].str.replace(r'([a-z](?=[A-Z])|[A-Z](?=[A-Z][a-z]))', r'\1 ').str.strip()

# %%
#Keep only unique entities
df['unq_GPE'] = df['GPE'].str.split(',').apply(pd.unique)
df['unq_FAC'] = df['FAC'].str.split(',').apply(pd.unique)
df['unq_LOC'] = df['LOC'].str.split(',').apply(pd.unique)
df['unq_ORG'] = df['ORG'].str.split(',').apply(pd.unique)
df[['GPE','unq_GPE']].loc[df['#GPE'] ==3]

# %%
df['unq_GPE'].dtype

# %%
# Data cleaning: Remove square brakets from location entities
df['unq_GPE'] =  df['unq_GPE'].astype(str).apply(lambda x: x.replace('[','').replace(']',''))
df['unq_FAC'] =  df['unq_FAC'].astype(str).apply(lambda x: x.replace('[','').replace(']',''))
df['unq_LOC'] =  df['unq_LOC'].astype(str).apply(lambda x: x.replace('[','').replace(']',''))
df['unq_ORG'] =  df['unq_ORG'].astype(str).apply(lambda x: x.replace('[','').replace(']',''))

# %%
df[['GPE','unq_GPE']].loc[df['#GPE'] ==3].head(10)

# %%
# Split with comma on unq entities
df['unq_GPE'] =  df['unq_GPE'].astype(str).replace('' '',',')
df[['GPE','unq_GPE']].loc[df['#GPE'] ==3].head(10)

# %%
df.to_csv('data//analysis_data//unique.csv')

# %% [markdown]
# # Final cleaned unique locations

# %%
df = pd.read_csv('data//analysis_data//unique_all_cleaned.csv')
df.head(3)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1       id  \
# 0           0           230            1311              1311  3411639
# 1           1           231            1315              1315  3412188
# 2           2           232            1320              1320  3412818
#
#    Unnamed: 4       date  \
# 0         NaN  05-Apr-20
# 1         NaN  10-Apr-20
# 2         NaN  11-Feb-20
#
#                                                                                                       en_text  \
# 0                             April 4 #fms_gratitude: a gray day that welcomes a fiery night. @ Boston Common
# 1  @_Amixem #lavueDepuismonfinement with the St. Lawrence Cach River by a snow tempt on April 10 ... #Quebec
# 2                                                                    I did mine February 11. @NASA be capping
#
#       source  longitude  ...                         LOC      TE #LOC #GPE  \
# 0  instagram -71.069230  ...                         NaN  Apr-04    0    0
# 1    Android -69.498244  ...  the St.Lawrence Cach River  Apr-10    0    0
# 2     iPhone -71.436234  ...                         NaN  Feb-11    0    0
#
#   #ORG #FAC unq_GPE        unq_FAC                     unq_LOC  unq_ORG
# 0    0    0     NaN  Boston Common                         NaN      NaN
# 1    0    0  Quebec            NaN  the St.Lawrence Cach River      NaN
# 2    0    0     NaN            NaN                         NaN     NASA
#
# [3 rows x 25 columns]

# %%
df =df.drop(columns =['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1','Unnamed: 0.1.1.1','Unnamed: 4'])
df.head(3)
# Out:
#         id       date  \
# 0  3411639  05-Apr-20
# 1  3412188  10-Apr-20
# 2  3412818  11-Feb-20
#
#                                                                                                       en_text  \
# 0                             April 4 #fms_gratitude: a gray day that welcomes a fiery night. @ Boston Common
# 1  @_Amixem #lavueDepuismonfinement with the St. Lawrence Cach River by a snow tempt on April 10 ... #Quebec
# 2                                                                    I did mine February 11. @NASA be capping
#
#       source  longitude  latittude lang     GPE            FAC   ORG  \
# 0  instagram -71.069230  42.356280   en     NaN  Boston Common   NaN
# 1    Android -69.498244  47.917575   fr  Quebec            NaN   NaN
# 2     iPhone -71.436234  41.850653   en     NaN            NaN  NASA
#
#                           LOC      TE  #LOC  #GPE  #ORG  #FAC unq_GPE  \
# 0                         NaN  Apr-04     0     0     0     0     NaN
# 1  the St.Lawrence Cach River  Apr-10     0     0     0     0  Quebec
# 2                         NaN  Feb-11     0     0     0     0     NaN
#
#          unq_FAC                     unq_LOC unq_ORG
# 0  Boston Common                         NaN     NaN
# 1            NaN  the St.Lawrence Cach River     NaN
# 2            NaN                         NaN    NASA

# %%
# replace all NaN with empty string
df = df.replace(np.nan, '', regex=True)
df.head()
# Out:
#         id       date  \
# 0  3411639  05-Apr-20
# 1  3412188  10-Apr-20
# 2  3412818  11-Feb-20
# 3  3413044  14-Feb-20
# 4  3413467  15-Jan-20
#
#                                                                                                                                                                                                                                                                 en_text  \
# 0                                                                                                                                                                                       April 4 #fms_gratitude: a gray day that welcomes a fiery night. @ Boston Common
# 1                                                                                                                                                            @_Amixem #lavueDepuismonfinement with the St. Lawrence Cach River by a snow tempt on April 10 ... #Quebec
# 2                                                                                                                                                                                                                              I did mine February 11. @NASA be capping
# 3                                                                                                                                                                                                                                                2/13 @ OnStage Atlanta
# 4  The view from the On The Green Magazine office. This is #Beachwood, 9:30 AM on January 15. It's already 70 degrees but later it's supposed to plunge down to 68. Time to plan your golf vacation!#myrtlebeach #myrtlebeachgolf #onthegreen #wintergolf #golfvacation
#
#       source  longitude  latittude lang      GPE            FAC  \
# 0  instagram -71.069230  42.356280   en           Boston Common
# 1    Android -69.498244  47.917575   fr   Quebec
# 2     iPhone -71.436234  41.850653   en
# 3  instagram -84.268230  33.793190   en  Atlanta
# 4  hootsuite -78.701422  33.813737   en
#
#                      ORG                         LOC      TE  #LOC  #GPE  \
# 0                                                     Apr-04     0     0
# 1                         the St.Lawrence Cach River  Apr-10     0     0
# 2                   NASA                              Feb-11     0     0
# 3               On Stage                              Feb-13     0     0
# 4  On The Green Magazine                              Jan-15     0     0
#
#    #ORG  #FAC  unq_GPE        unq_FAC                     unq_LOC  \
# 0     0     0           Boston Common
# 1     0     0   Quebec                 the St.Lawrence Cach River
# 2     0     0
# 3     0     0  Atlanta
# 4     0     0
#
#                  unq_ORG
# 0
# 1
# 2                   NASA
# 3               On Stage
# 4  On The Green Magazine

# %%
# Counting comma separated entities
df['#LOC2'] = df['unq_LOC'].str.count(',')
df['#GPE2'] = df['unq_GPE'].str.count(',')
df['#ORG2'] = df['unq_ORG'].str.count(',')
df['#FAC2'] = df['unq_FAC'].str.count(',')
df[['GPE','#GPE','unq_GPE','#GPE2']].head(10)
# Out:
#                       GPE  #GPE            unq_GPE  #GPE2
# 0                             0                         0
# 1                  Quebec     0             Quebec      0
# 2                             0                         0
# 3                 Atlanta     0            Atlanta      0
# 4                             0                         0
# 5  Youngstown,Japan,Japan     2  Youngstown, Japan      1
# 6                   Idaho     0              Idaho      0
# 7                             0                         0
# 8                             0                         0
# 9                             0                         0

# %%
df.to_csv('data//analysis_data//unique_all_cleaned.csv')

# %%
df.columns
# Out:
# Index(['id', 'date', 'en_text', 'source', 'longitude', 'latittude', 'lang',
#        'GPE', 'FAC', 'ORG', 'LOC', 'TE', '#LOC', '#GPE', '#ORG', '#FAC',
#        'unq_GPE', 'unq_FAC', 'unq_LOC', 'unq_ORG', '#LOC2', '#GPE2', '#ORG2',
#        '#FAC2'],
#       dtype='object')

# %% [markdown]
# ## Discard GPE > 1 comma

# %%
df[['FAC','unq_FAC','#FAC','#FAC2']].loc[df['#FAC'] >=2]
# Out:
#                                                                                                    FAC  \
# 37                                                           Park Ave,Park Ave,Park Avenue,94th Street
# 383      Washington Avenue Corridor Historic District!U Albany,Washington Avenue,the Schuyler Building
# 1225                                                                     24th,Mechanic,the Powell Arch
# 1318                                      Cherokee Street,Boone Drive,Big Shanty Drive,Pine Hill Drive
# 1652                                                          Rodeo,NRG Stadium,Astrodome,RODEOHOUSTON
# 1732                                               Dale Street Shaw,St Thomas Church Hall,Glebe Street
# 2339                                                                    MLKDRIVE.,30th Ave,Lincoln Way
# 2398                                                                                        UA,SFO,LAX
# 2432                                                   Bryant Park,Winter Village,Bryant Park Ice Rink
# 2788                                                                            Metro2033,VDN Kh,Metro
# 2792                                                                  Highway9,MP93,Swan Mountain Road
# 2896                                                          1-70W,Paris Rd,the Missouri River Bridge
# 4728                                                         280north,pedestrianoverpass,sanjoseavenue
# 5123                                                                         HEAVEN,JFK,RUNAWAYJURY.We
# 5128                                                                         230,Des Plaines Metra,330
# 5194                                                    Borough Market,Edgware Road,Victoria,Hyde Park
# 5195                                                           Innes,Merritt,Lakewood Apts,Merritt Ave
# 5249                                                                                  CVS,C Us,Clinton
# 5665                                                                            Donaghey,Scott,College
# 5983                                                          uphamscornercornerof,Columbia Rd,Bird St
# 6435                                       Rupp Arena,Central Bank Center,Orange Julius,the Food Court
# 6674                                                                                       MBTA,Line,T
# 6720                                                                                   Metro,WUS,Metro
# 7708                                                                        Queen Street,Queen,Spadina
# 7790                                                                         Transit Center,Cota,State
# 7932                 New Rochelle School Food Distribution Locations,Bracey,95Lincoln,Bracey,95Lincoln
# 8140                                                           Ralph Road,Arnold Ave,Woodland Hills Dr
# 8578   Lake Compounce Yankee,Canoby Lake Park Ghostrider,Knotts Berry Farm Gemini,Cedar Point Renegade
# 9011                                                           Frick Park,Forbes Ave,Tranquil&Homewood
# 9155                                                          Kessler Park,Gladstone Blvd,Lawndale Ave
# 11343                                                                       Google Shuttle,18th,Castro
# 11725                                                                 MUNI Bus Stop,California,6th Ave
# 12747                                                          Richmond Amtrak Station,Main Street,RVM
# 12939                                                              Mo MA,Mo MA,The Museumof Modern Art
# 13424                                Kangamoo Indoor Playground,Sunset Road,Kangamoo Indoor Playground
# 13518                                                       South Street,Brooklyn Bridges,South Street
# 13874                                                             St.Patrick,Holycross,Mary Immaculata
# 14170                              Meridian Arts Centre,Meridian Arts Centre,Toronto Centreforthe Arts
# 14517                                                                 Mall,Smithsonian,Washington Mall
# 14727                     the White Sox Restaurant,Midway Airport,Chicago Midway International Airport
# 17084                                                                     Apple Visitor Center,Idi,NMU
# 17215                                 No Blvdtrafficlights.,Saltillo400,Transitotorreon,Encion Torreon
# 17456                                                         4GBUDEI,KADM,Bohuel10Homeless,Kadm,Londn
#
#                                                                                                    unq_FAC  \
# 37                                                                      Park Ave, Park Avenue, 94th Street
# 383       Washington Avenue Corridor Historic District!U Albany\n Washington Avenue, the Schuyler Building
# 1225                                                                       24th, Mechanic, the Powell Arch
# 1318                                       Cherokee Street, Boone Drive, Big Shanty Drive, Pine Hill Drive
# 1652                                                           Rodeo, NRG Stadium, Astrodome, RODEOHOUSTON
# 1732                                                 Dale Street Shaw, St Thomas Church Hall, Glebe Street
# 2339                                                                      MLKDRIVE., 30th Ave, Lincoln Way
# 2398                                                                                          UA, SFO, LAX
# 2432                                                     Bryant Park, Winter Village, Bryant Park Ice Rink
# 2788                                                                              Metro2033, VDN Kh, Metro
# 2792                                                                    Highway9, MP93, Swan Mountain Road
# 2896                                                            1-70W, Paris Rd, the Missouri River Bridge
# 4728                                                           280north, pedestrianoverpass, sanjoseavenue
# 5123                                                                           HEAVEN, JFK, RUNAWAYJURY.We
# 5128                                                                           230, Des Plaines Metra, 330
# 5194                                                     Borough Market, Edgware Road, Victoria, Hyde Park
# 5195                                                            Innes, Merritt, Lakewood Apts, Merritt Ave
# 5249                                                                                    CVS, C Us, Clinton
# 5665                                                                              Donaghey, Scott, College
# 5983                                                            uphamscornercornerof, Columbia Rd, Bird St
# 6435                                        Rupp Arena, Central Bank Center, Orange Julius, the Food Court
# 6674                                                                                         MBTA, Line, T
# 6720                                                                                            Metro, WUS
# 7708                                                                          Queen Street, Queen, Spadina
# 7790                                                                           Transit Center, Cota, State
# 7932                                    New Rochelle School Food Distribution Locations, Bracey, 95Lincoln
# 8140                                                             Ralph Road, Arnold Ave, Woodland Hills Dr
# 8578   Lake Compounce Yankee, Canoby Lake Park Ghostrider\n Knotts Berry Farm Gemini, Cedar Point Renegade
# 9011                                                             Frick Park, Forbes Ave, Tranquil&Homewood
# 9155                                                            Kessler Park, Gladstone Blvd, Lawndale Ave
# 11343                                                                         Google Shuttle, 18th, Castro
# 11725                                                                   MUNI Bus Stop, California, 6th Ave
# 12747                                                            Richmond Amtrak Station, Main Street, RVM
# 12939                                                                       Mo MA, The Museumof Modern Art
# 13424                                                              Kangamoo Indoor Playground, Sunset Road
# 13518                                                                       South Street, Brooklyn Bridges
# 13874                                                               St.Patrick, Holycross, Mary Immaculata
# 14170                                                      Meridian Arts Centre, Toronto Centreforthe Arts
# 14517                                                                   Mall, Smithsonian, Washington Mall
# 14727                      the White Sox Restaurant, Midway Airport\n Chicago Midway International Airport
# 17084                                                                       Apple Visitor Center, Idi, NMU
# 17215                                  No Blvdtrafficlights., Saltillo400, Transitotorreon, Encion Torreon
# 17456                                                         4GBUDEI, KADM, Bohuel10Homeless, Kadm, Londn
#
#        #FAC  #FAC2
# 37        3      2
# 383       2      1
# 1225      2      2
# 1318      3      3
# 1652      3      3
# 1732      2      2
# 2339      2      2
# 2398      2      2
# 2432      2      2
# 2788      2      2
# 2792      2      2
# 2896      2      2
# 4728      2      2
# 5123      2      2
# 5128      2      2
# 5194      3      3
# 5195      3      3
# 5249      2      2
# 5665      2      2
# 5983      2      2
# 6435      3      3
# 6674      2      2
# 6720      2      1
# 7708      2      2
# 7790      2      2
# 7932      4      2
# 8140      2      2
# 8578      3      2
# 9011      2      2
# 9155      2      2
# 11343     2      2
# 11725     2      2
# 12747     2      2
# 12939     2      1
# 13424     2      1
# 13518     2      1
# 13874     2      2
# 14170     2      1
# 14517     2      2
# 14727     2      1
# 17084     2      2
# 17215     3      3
# 17456     4      4

# %%
df.shape
# Out:
# (18510, 24)

# %%
df_final = df.loc[df['#GPE2'] <=1]
df_final.shape
# Out:
# (18226, 24)

# %%
df_final = df_final.loc[df['#LOC2'] <=1]
df_final.shape
# Out:
# (18219, 24)

# %%
df_final = df_final.loc[df['#FAC2'] <=1]
df_final.shape
# Out:
# (18183, 24)

# %%
df_final = df_final.loc[df['#ORG2'] <=1]
df_final.shape
# Out:
# (17969, 24)

# %%
df_final.columns
# Out:
# Index(['id', 'date', 'en_text', 'source', 'longitude', 'latittude', 'lang',
#        'GPE', 'FAC', 'ORG', 'LOC', 'TE', '#LOC', '#GPE', '#ORG', '#FAC',
#        'unq_GPE', 'unq_FAC', 'unq_LOC', 'unq_ORG', '#LOC2', '#GPE2', '#ORG2',
#        '#FAC2'],
#       dtype='object')

# %%
df_final = df_final.drop(columns = ['#LOC', '#GPE', '#ORG', '#FAC', 'GPE', 'FAC', 'ORG', 'LOC', '#LOC2', '#GPE2', '#ORG2', '#FAC2'])
df_final.columns
# Out:
# Index(['id', 'date', 'en_text', 'source', 'longitude', 'latittude', 'lang',
#        'TE', 'unq_GPE', 'unq_FAC', 'unq_LOC', 'unq_ORG'],
#       dtype='object')

# %%
df_final = df_final.rename(columns = {'unq_GPE':'GPE','unq_FAC':'FAC', 'unq_LOC':'LOC', 'unq_ORG':'ORG' })
df_final.columns
# Out:
# Index(['id', 'date', 'en_text', 'source', 'longitude', 'latittude', 'lang',
#        'TE', 'GPE', 'FAC', 'LOC', 'ORG'],
#       dtype='object')

# %%
df_final.head(10)
# Out:
#         id       date  \
# 0  3411639  05-Apr-20
# 1  3412188  10-Apr-20
# 2  3412818  11-Feb-20
# 3  3413044  14-Feb-20
# 4  3413467  15-Jan-20
# 5  3414717  15-Feb-20
# 6  3416128  15-Apr-20
# 7  3416192  19-Mar-20
# 8  3416548  04-Jan-20
# 9  3418141  21-Apr-20
#
#                                                                                                                                                                                                                                                                 en_text  \
# 0                                                                                                                                                                                       April 4 #fms_gratitude: a gray day that welcomes a fiery night. @ Boston Common
# 1                                                                                                                                                            @_Amixem #lavueDepuismonfinement with the St. Lawrence Cach River by a snow tempt on April 10 ... #Quebec
# 2                                                                                                                                                                                                                              I did mine February 11. @NASA be capping
# 3                                                                                                                                                                                                                                                2/13 @ OnStage Atlanta
# 4  The view from the On The Green Magazine office. This is #Beachwood, 9:30 AM on January 15. It's already 70 degrees but later it's supposed to plunge down to 68. Time to plan your golf vacation!#myrtlebeach #myrtlebeachgolf #onthegreen #wintergolf #golfvacation
# 5                                                   Youve been a piece of my heart since January 2016. Youngstown wont be the same after you travel back to Japan, but I know that youll be a ray of sunshine anywhere you go. #LoveHer #RayOfSunshine #Japan #Japanese
# 6                                                                  Ready, set, order... Only for free delivery in Treasure Valley (Idaho)... Order online at Orders made by April 16, 5pm MST will be eligible for Unicorn, Sakasquatch and Beanie drawing. Join us for
# 7                                                                                                                                                                                                                     Ava combos! 3/19 @ Tong Dragon Mixed Martial Arts
# 8                                                                                                                                                                                                   2020/1/4: - Drinking an Oatology by @imprintbeer @ Imprint Beer Co.
# 9                                                                                                                                                                                                                                        Weekly NYC Covid19 report 4/20
#
#       source   longitude  latittude lang          TE                GPE  \
# 0  instagram  -71.069230  42.356280   en      Apr-04
# 1    Android  -69.498244  47.917575   fr      Apr-10             Quebec
# 2     iPhone  -71.436234  41.850653   en      Feb-11
# 3  instagram  -84.268230  33.793190   en      Feb-13            Atlanta
# 4  hootsuite  -78.701422  33.813737   en      Jan-15
# 5  instagram  -80.649210  41.098610   en      Jan-16  Youngstown, Japan
# 6  instagram -116.390330  43.611290   en      Apr-16              Idaho
# 7  instagram  -74.172632  39.908788   en      Mar-19
# 8    untappd  -75.284000  40.264000   en  04/01/2020
# 9     iPhone  -73.883894  40.665907   en      Apr-20
#
#                               FAC                         LOC  \
# 0                   Boston Common
# 1                                  the St.Lawrence Cach River
# 2
# 3
# 4
# 5
# 6                                             Treasure Valley
# 7  Tong Dragon Mixed Martial Arts
# 8
# 9
#
#                      ORG
# 0
# 1
# 2                   NASA
# 3               On Stage
# 4  On The Green Magazine
# 5
# 6
# 7
# 8       Imprint Beer Co.
# 9           NYC, Covid19

# %%
df_final.to_csv('geocoding//data//final_posts.csv')

# %% [markdown]
# # Preparing geocoding locations

# %%
df = pd.read_csv('geocoding//data//final_posts.csv')
df.shape
# Out:
# (17969, 13)

# %%
# Print number of unique entities
print("Number of unique values:")
print("\n GPE =", df['GPE'].nunique(), "\n ORG =", df['ORG'].nunique(), "\n LOC =", df['LOC'].nunique(), "\n FAC =", df['FAC'].nunique())
# Out:
# Number of unique values:
#
#  GPE = 4197
#  ORG = 6125
#  LOC = 702
#  FAC = 3000

# %%
# replace all NaN with empty string
df = df.replace(np.nan, '', regex=True)
df.head()
# Out:
#    Unnamed: 0       id       date  \
# 0           0  3411639  05-Apr-20
# 1           1  3412188  10-Apr-20
# 2           2  3412818  11-Feb-20
# 3           3  3413044  14-Feb-20
# 4           4  3413467  15-Jan-20
#
#                                                                                                                                                                                                                                                                 en_text  \
# 0                                                                                                                                                                                       April 4 #fms_gratitude: a gray day that welcomes a fiery night. @ Boston Common
# 1                                                                                                                                                            @_Amixem #lavueDepuismonfinement with the St. Lawrence Cach River by a snow tempt on April 10 ... #Quebec
# 2                                                                                                                                                                                                                              I did mine February 11. @NASA be capping
# 3                                                                                                                                                                                                                                                2/13 @ OnStage Atlanta
# 4  The view from the On The Green Magazine office. This is #Beachwood, 9:30 AM on January 15. It's already 70 degrees but later it's supposed to plunge down to 68. Time to plan your golf vacation!#myrtlebeach #myrtlebeachgolf #onthegreen #wintergolf #golfvacation
#
#       source  longitude  latittude lang      TE      GPE            FAC  \
# 0  instagram -71.069230  42.356280   en  Apr-04           Boston Common
# 1    Android -69.498244  47.917575   fr  Apr-10   Quebec
# 2     iPhone -71.436234  41.850653   en  Feb-11
# 3  instagram -84.268230  33.793190   en  Feb-13  Atlanta
# 4  hootsuite -78.701422  33.813737   en  Jan-15
#
#                           LOC                    ORG
# 0
# 1  the St.Lawrence Cach River
# 2                                               NASA
# 3                                           On Stage
# 4                              On The Green Magazine

# %%
df['LOC'].unique()
# Out:
# array(['', 'the St.Lawrence Cach River', 'Treasure Valley',
#        'Georgian Bay', 'Hill Valley', 'bayridge', 'Valley',
#        'Latin America', 'Red River', 'Heaven Hill', 'Deep Creek North',
#        'South Texas', 'Washington Heights', 'Mars', 'Old Sacramento',
#        'Centennial Hills', 'the Hudson Valley',
#        'Jeffery Epsteins, Doucheowotz', 'Lake Bluff, Lakebluff',
#        'New England', 'Nevada', 'South', 'Rose Hill', 'Lost Cities',
#        'Lake Braddock', 'Bayarea', 'ELCENTROCALIFORNIA', 'West, East',
#        'Germantown Ave', 'South Miami', 'Sugarland', 'valley',
#        'Las Vegas Strip', 'Colorado National Monument', 'So Cal',
#        'the Great Northwest', 'the Tidal Basin', 'Cheyenne Mountain',
#        'NORTHKOREA', 'Europe', 'DC', 'Earth', 'the French Quarter',
#        'Las Trampas', 'Jordan River', 'Forth Ward', 'WY', 'Himalayas',
#        'White Mountainsof Arizona', 'saltlake', 'the Gaslight District',
#        'North Buffalo', 'Redblacks', '6thstreet', 'Bayside', 'Lake Tahoe',
#        '53rd Congressional', 'Greenwich', 'Buena Vista Neighborhood',
#        'Maine', 'Mt.Brook', 'Peak Turnip', 'the Rocky Mountains',
#        'La Grange', '2ndave', 'Carroll Gardens',
#        'Pikes Peak Americas Mountain', 'Garden State', 'Hudson Yards',
#        'Gorge', 'the Bay Area', 'Long Island', 'No Ho Arts District',
#        'Harlem', 'Live Oak Lake', 'Antarctica', 'thebestcoast',
#        'Alvins Island, Tropical Waves', 'Forest Glade', 'the East Valley',
#        'Mt.Esja', 'Pikes Peak', 'Beach', 'Caribbean', 'Grapevinelake',
#        'Highland', 'North Hollywood', 'Acela', 'Tomorrowland',
#        'Deer Park', 'Irelandsway', 'PNW', 'Golden Gardens',
#        'Navadafalls, Yosemite', 'Burnside', 'East Village',
#        'Little Mashel River Waterfalls', 'Topof Mt.Lincoln, Sugar Bowl',
#        'The Bay Area', 'Miami Beach', 'Mill Mountain', 'Moss Glen Falls',
#        'East Falls', 'Sebastian Cir', 'Pico Mountain', 'Isaac Garza',
#        'Central USA', 'the South Side', 'Central Park, Midtown South',
#        'Future City', 'theeastside', 'the East Hill', 'DTLA', 'SF',
#        'Irelands', 'Distillery District', 'Asia', 'Virginia', 'SLU',
#        'Hermitage', 'North Conway', 'North, North Florida', 'Ocean Beach',
#        'Yellowstone', 'AMountain', 'pacific', 'Midwest', 'Grand Canyon',
#        'themiddlewest', 'Northside', 'New Mexico', 'Central Maine',
#        'Wolverine Country', 'thefoxriver',
#        'the New Rochelle Containment Zone\n New York State Emergency Operation Center',
#        'New Rochelle', 'thebig Apple', '10thdistrictof Florida',
#        'Tampabay', 'Southgate', 'South Jersey', 'Hampden', 'West Texas',
#        'South Florida', 'the North Loop', 'Land', 'Central Indiana',
#        'the Middle East', 'Mediterranean', 'Southern California',
#        'Upper East Side', 'Upper Gwinn Commons', 'NWAL', 'North Alabama',
#        'NV', 'St Charles', 'Ktown', 'Gold Rush', 'clearlakeavenue',
#        'Minnesota Headass', 'Issaquah Creek Flood', 'Issaquah Creek',
#        'Possumhollow', 'centro', 'midland', 'North Georgia',
#        'the Vegasvalley', 'Botanic Gardens', 'Saint Paul', 'Crimea',
#        'Slum Village', 'North Metro', 'Eastcoast', 'Westchester',
#        'Oak Hill, Piedmont Park', 'Bay',
#        'South Beachthismorningwitha Super Forecast!', '8th Ave',
#        'Bostonati Heart Radio', 'East Coast', 'New England, Midwest',
#        'the Southeastern U.S.', 'Miami/Broward Up', 'the Edgewater Area',
#        'Greenland', 'Green Acres', 'lakesuperior', 'northernliberties',
#        'the Uncanny Valley', 'Westchester County',
#        'East Ellijay, Rich Mountain', '11th', 'the Backyard', 'East',
#        'Lake Union', 'Tunnel Creek', 'tinkerscreek', 'Texas Lake',
#        'North Shore', 'Pacific, Middle America', 'Atlantic Coast',
#        'Woodland', 'Crystal City', 'Downtown Nashville', '10th St.', 'AL',
#        'Dark Forest', 'Queens', 'West Virginia', 'Ocean', 'Mt', 'Osborn',
#        'Cali', 'NFC East', 'bay', 'Metropolis', 'Lake Oswego',
#        'North Houston', 'Times Square', 'the North End', 'Little Saigon',
#        'Beverlyhills', 'ravenvalleyroad', 'bluffsnaturearea',
#        'Boones Farm?You, Strawberry Hill?Again', '10th Street',
#        'North Hills', 'Rabbit Valley', 'Northern MN', 'Missouri Valley',
#        'the Pacific North West', 'Northern Iowa', 'Monarchpark',
#        '3rd Street', 'Montral', 'District', 'Oyster', 'Islay',
#        'panoramacity', 'The Cliffsof Moher', 'Delaware', 'Fallen Timbers',
#        'eurasia', 'Dover Beach', 'Europa, Enceladus', 'NE', 'eastcoast',
#        'Europa', 'Capitol Corridor', 'SALTLAKE', 'Jupiter',
#        'Lake Superior', 'Great Lake', 'the Valley UNI', '6th',
#        'Pearl River', 'Pleistocene Park', 'Uptown', 'Mountain View',
#        'Downtown', 'oceancity', 'The Midlands', 'thewestcoast', 'India',
#        'Southern Illinois', 'the West Coast', 'Illinois', 'cherryvalley',
#        'No VA', 'North Dakota', 'the Faroe Islands', 'Honey Island',
#        'Mountain Valley', 'Sweet Home Alabama', 'caphill',
#        'the Pacific Northwest', 'North Star',
#        'Long Island, Liberty Island', 'ATL', 'Castle Hills', 'Lopez Lake',
#        'Riverside', 'the San Gabriel Valley', '12th',
#        'the Upper Westside', 'Silicon Valley', 'South End, Mercer Island',
#        '2nd', '41st', 'farrockaway', 'Enceladus, Europa',
#        'Cascade, North Bend', 'North Westgreen', 'Le Marais', 'Pit',
#        'Western PA', 'tundra', 'the Great White North', 'South Bend',
#        'Hood River', 'the Rust Belt', 'Central Park',
#        'Yosemitenationalpark', 'Bay Area', 'South Dakota', 'theeastcoast',
#        'NA East', 'Lake Louise', 'Michigan', 'Americas', 'dmv', 'Ghut',
#        'Atlantis', 'Palm Beach Island', 'Eastern Oklahoma',
#        'Containment Area Zone', 'New Rochelle Containment Site',
#        'Cape Cod', 'California', 'Wykagyl, the Containment Zone', 'So.IL',
#        'Baldwin Park', 'california', 'Metro Detroit', 'Purgatory',
#        'Shemp', 'the New Rochelle Containment Zone', 'Northside Park',
#        'Cliff Mass', 'Lowcountry', 'Atlantic', 'earth',
#        'South Endofthe City', 'Bird Springs Valley', 'thegrandcanyon',
#        'Westcoast', 'southbend', 'Deep State', 'Appalachians',
#        'siliconvalley', 'detroitarea', 'HEAVEN', 'Snowshoe',
#        'northfoxisland, Lake Michigan',
#        'Andre Clark Bird Refuge, Santa Ynez', 'Texas Spring',
#        'Metro Atlanta', 'East York', 'mountain', 'Lake Shore',
#        'Charm City', 'Wykagyl', 'Niagara Falls', 'SOUTHCHICAGO',
#        'THESOUTH', 'the Isleof Skye', 'New Hope', 'South America',
#        'Lake Ontario', 'Le Blanc', 'Rockland County South', 'SWDC',
#        'St Cloud', 'Upper Cape Cod', 'Corona', 'Westside', 'Mississippi',
#        'the Chesapeake Bay', 'Moorside', 'San Brunomountain', 'Tjornin',
#        'Lake Effect', 'Music City', 'thegreatwhitenorth',
#        'Holeinthe Wallbeach', 'fort Knox', 'Pointe Plaza',
#        'Tachinomiarea', 'SFO', 'Mount Rainier', 'the Hudsonriver',
#        'Wykagyl Neighborhood', 'Hawaii', 'NORTHAL', 'the Bisti Badlands',
#        'Southbeach', 'Forrest', 'bayarea',
#        'the Pacificislands, the South Pacific', 'montana', 'Vh River',
#        'Silicon Valleys', 'Illinois River River', 'Minnesota',
#        'Western Australia', 'Indies, Greenland', 'fairisle',
#        'Lakeofthe Isles', 'Eastern Shore', 'Shutterfly', 'Old Town',
#        'dabay', 'San Gabriel Valley', 'Davis Islands', 'the Lower Level',
#        'Mars, Jupiter', 'Austins', '47th Terrace East', 'Outer Sunset',
#        'Universe', 'Marina', 'gooseisland', 'Seneca', 'Clay',
#        'Moustache Mountain', 'Casscounty', 'Instagram',
#        'Huntington Park/Cudahyarea', 'Tillamook', 'Sac', 'Whidbey',
#        'Schittscreek', 'Pacific', 'Kansas', 'Ballard', 'Smiland Island',
#        'Floridas', 'Jurassic Park', 'Spokane', 'Hudson', 'North Africa',
#        'mountians', 'Pennsylvania', 'Temperance Alley',
#        'Bay City?Thousands', 'Ghost Town', 'Lake Seminole',
#        'Elk Mountain', 'brickcity', 'Sea', 'Key West',
#        'the Orange Estates', 'Chesapeake Bay', 'PAK, DLD', 'Tule',
#        'Camden', 'Myford', 'Santa Susana Pass', 'SEA', 'Monroecounty',
#        'French Valley', 'Middle East', 'Nile', 'West Seattle',
#        '11th, Vermont', 'Hills', 'northwest', 'Smokey Mountains', 'RVA',
#        'South Hyde Park', 'University District',
#        'Winnetka Heights Historic District', 'Venice Beach',
#        'Wynnewood North Neighborhood', 'Hyde Park Hobbit Hole',
#        '3rd Floor', 'Wood Avenue Historic District',
#        'San Diego Seaworld-Beach Area', 'Pacific Beach', 'Lake Nona',
#        'East Flatbush', 'West Virginia State Line', 'Otay Mesa',
#        'Carol Stream', 'SD', 'West End Theatre District',
#        'Main Street District', 'Waters Edge Neighborhood.',
#        'The Skunks Hideout', 'North Wildwood Inlet', 'East Penn Twp',
#        'Cascata Lakes', 'Downtown Cleveland', 'Des Moinesriver',
#        'Belmont Shore', 'Lower Pacific Heights', 'Mount Arlington ',
#        'Echo Park Lake', 'Sierra Highway', 'Palisades Corner',
#        'Ma RS Discovery District', 'East Harlem', 'Temecula Valley',
#        'Downtown San Diego', 'Financial District', 'Traverse Mountain',
#        'Econlockhatchee Sandhills Conservation Area', 'East Lake Toho',
#        'Villa Park', 'Cathedral Heights', 'Winter Park', 'El Cap',
#        'West Loop', 'Sturdivant Falls, Sturtevant Falls', 'Longs Peak',
#        'East New York', 'the Outer Banks', 'Cultus Lake',
#        'Lake Arrowhead', 'Manta', 'North Gates',
#        '9th Congressional District', 'North East', 'Tribeca Park',
#        'Catalina Foothills', 'American Canyon', 'Central District',
#        'John Day River', 'Willow Oaks', 'Montauk End Of The World',
#        'Cherry Beach', 'Mission Beach Sunset', 'Galaxys Edge',
#        'French Quarter', 'Manhattan', 'Stow Lake', 'Ocotillo Hill',
#        'the Superstition Mountains!', 'Ozarks',
#        'Winter Garden Downtown Historic District',
#        'the St Johns River Sisters Creek', 'Central Coast',
#        'the Big Apple', 'Sinclair Island', 'Marble Hill',
#        'Third Street South', 'Brewery District', 'Upper West Side',
#        'Desert', 'the West End, Cascade', 'Florida Keys',
#        '7th Ward, New Orleans', 'Red Rock-Secret Mountain Wilderness',
#        'New York Harbor', 'the White Mountains', 'Stone Mountain',
#        'North Auburn', 'Cape', 'Shark Fin Cove Beach', 'Rodeo Beach',
#        'Lower Yosemite Falls', 'Clovis Veterans Memorial District',
#        'Chinatown', 'Lake Chemong', 'Lake Pleasant', 'Wisconsin',
#        'El Chorro', 'Highline Park', 'Cherokee Triangle', 'Monterey Park',
#        'Nine Mile Falls', 'Richland Center', 'Melrose Ave', 'South Point',
#        'Mount Snow', 'Dragon Light', 'Jersey City Heights',
#        'Earth, Grand Canyon', 'Shaw Historic District',
#        'Visitacion Valley', 'Southeast', 'Squaw Valley', 'Trabuco Canyon',
#        'Central City', 'Riversidecounty Sci', 'East Baltimore ',
#        'Eastern Colorado', 'West Side',
#        'The Middle Fork, the Feather River', 'Taylor Ranch',
#        'South Mountain', 'the Rio Grande', 'Down Under', 'Park Lake',
#        'Lower East Side', 'False Cape, Back Bay National Wildlife Refuge',
#        'the Hollywood Hills, Hollywood Hills', '13th Ave S', 'United',
#        'Sharon Harris Lake', 'Mysticseaport', 'the Northern Hemisphere',
#        'North Raleigh', 'Eastlake Woods',
#        'Nobility Hill Historic District', 'South Beach',
#        'New York Central Park', 'Mecca', 'Oaxaca', 'the Fan Zone',
#        'Garment District', 'Skyline Gate Stagin Area', 'Grey Highlands',
#        'Lake Sammamish', 'castletonsquare', 'Village', 'Sullivans Island',
#        'theseKingdom Streets', 'Downtown Tampa', 'South Shore',
#        'Lake Jackson', 'Fort Hill Rural Historic District',
#        'Chicago Loop', 'Mammoth Lakes', 'Lake Granbury',
#        'the NEWYORKAREA', 'Ball Ground', 'North America',
#        'Park View Historic District', 'Turtle Island', 'Clifton Park',
#        'Lake Ida Park', 'Port Saint Lucie', 'Welsh Road',
#        'Discovery Park', 'Saint Marys Glacier', '7th Ward',
#        'Death Valley', 'Wolf Trap Creek', 'Fryman Canyon Trailhead',
#        'Carleton Place', 'West Village',
#        'lospadresnationalforest, Rattlesnake Canyon Trail',
#        'Downtown Portland', 'South Bay Marina', 'Zion National Park',
#        'South Beach, Beach', 'North Shasta Trinity, Greater Tehama',
#        'the Gulfport Art District', 'Lake Weir', 'Warrendale',
#        'the Rogue Valley', 'the La Crosse Region', 'the98thmeridian',
#        'Central Illinois', 'Devon', 'the North Country', 'Biscayne Bay',
#        'Metrowest', 'Mini City', 'Grand Rapids East Beltline',
#        'Colonial Heights', 'Filo Field', 'Quarry Park', 'Marina City',
#        'Artsian Lakes', 'Hyde Park', 'Railroad District', 'Paugus Bay',
#        'Long Mountain Wayside', 'Flagstaff Lake', 'Newtown Square',
#        'Hidden Cove', 'Dali Quarantine', 'Ann Taylor Park', 'new FR',
#        'Port Aransasbeach', 'Carushowlakes', 'Tenochtitlanstreet',
#        'Sunset', 'La Ribera', 'palmsprings', 'Miles', 'San Blas2ndsector',
#        'Northern Mexico', 'Calle Platn', 'Keroncong', 'Gala Rala',
#        'Torren', 'Liberty Dam', 'Mermaid', 'South Dixie', 'DAYARD',
#        'Wasteland', 'Green Room', 'Old Mexico', 'Havasu Falls',
#        'Poop Lake', 'Wappinger Lake', 'Fuji', 'Adams Canyon',
#        'Lake Cyrus', 'La Jolla Cove', 'Palmetto Bay Marina', 'West End',
#        'New York Streets', 'Gustavo Daz Ordaz', 'Eureka Valley',
#        'Mount Rubidoux', 'South Las Vegas', 'Shelter Island',
#        'Volcano Bay', 'Green Valley'], dtype=object)

# %%
# Combining locational entities to get finer and more informed place names
# Locations are combined only when both columns are not null

df['FAC_GPE'] = np.where(((df['FAC'] != '') & (df['GPE'] != '')), df['FAC'].str.cat(df['GPE'], sep = ", "), '')
df['ORG_GPE'] = np.where(((df['ORG'] != '') & (df['GPE'] != '')), df['ORG'].str.cat(df['GPE'], sep = ", "), '')
df['LOC_GPE'] = np.where(((df['LOC'] != '') & (df['GPE'] != '')), df['LOC'].str.cat(df['GPE'], sep = ", "), '')

df['FAC_LOC'] = np.where(((df['FAC'] != '') & (df['LOC'] != '')), df['FAC'].str.cat(df['LOC'], sep = ", "), '')
df['ORG_LOC'] = np.where(((df['ORG'] != '') & (df['LOC'] != '')), df['ORG'].str.cat(df['LOC'], sep = ", "), '')

df['LOC_FAC'] = np.where(((df['LOC'] != '') & (df['FAC'] != '')), df['LOC'].str.cat(df['FAC'], sep = ", "), '')
df['FAC_ORG'] = np.where(((df['FAC'] != '') & (df['ORG'] != '')), df['FAC'].str.cat(df['ORG'], sep = ", "), '')

df['ORG_FAC'] = np.where(((df['ORG'] != '') & (df['FAC'] != '')), df['ORG'].str.cat(df['FAC'], sep = ", "), '')
df['LOC_ORG'] = np.where(((df['LOC'] != '') & (df['ORG'] != '')), df['LOC'].str.cat(df['ORG'], sep = ", "), '')
df.head(2)
# Out:
#    Unnamed: 0       id       date  \
# 0           0  3411639  05-Apr-20
# 1           1  3412188  10-Apr-20
#
#                                                                                                       en_text  \
# 0                             April 4 #fms_gratitude: a gray day that welcomes a fiery night. @ Boston Common
# 1  @_Amixem #lavueDepuismonfinement with the St. Lawrence Cach River by a snow tempt on April 10 ... #Quebec
#
#       source  longitude  latittude lang      TE     GPE  ... ORG FAC_GPE  \
# 0  instagram -71.069230  42.356280   en  Apr-04          ...
# 1    Android -69.498244  47.917575   fr  Apr-10  Quebec  ...
#
#   ORG_GPE                             LOC_GPE FAC_LOC ORG_LOC LOC_FAC FAC_ORG  \
# 0
# 1          the St.Lawrence Cach River, Quebec
#
#   ORG_FAC LOC_ORG
# 0
# 1
#
# [2 rows x 22 columns]

# %%
df['FAC_LOC_GPE'] = np.where(((df['FAC_LOC'] != '') & (df['GPE'] != '')), df['FAC_LOC'].str.cat(df['GPE'], sep = ", "), '')
df['ORG_LOC_GPE'] = np.where(((df['ORG_LOC'] != '') & (df['GPE'] != '')), df['ORG_LOC'].str.cat(df['GPE'], sep = ", "), '')
df['LOC_FAC_GPE'] = np.where(((df['LOC_FAC'] != '') & (df['GPE'] != '')), df['LOC_FAC'].str.cat(df['GPE'], sep = ", "), '')
df['FAC_ORG_GPE'] = np.where(((df['FAC_ORG'] != '') & (df['GPE'] != '')), df['FAC_ORG'].str.cat(df['GPE'], sep = ", "), '')
df['ORG_FAC_GPE'] = np.where(((df['ORG_FAC'] != '') & (df['GPE'] != '')), df['ORG_FAC'].str.cat(df['GPE'], sep = ", "), '')
df['LOC_ORG_GPE'] = np.where(((df['LOC_ORG'] != '') & (df['GPE'] != '')), df['LOC_ORG'].str.cat(df['GPE'], sep = ", "), '')
df.head(2)
# Out:
#    Unnamed: 0       id       date  \
# 0           0  3411639  05-Apr-20
# 1           1  3412188  10-Apr-20
#
#                                                                                                       en_text  \
# 0                             April 4 #fms_gratitude: a gray day that welcomes a fiery night. @ Boston Common
# 1  @_Amixem #lavueDepuismonfinement with the St. Lawrence Cach River by a snow tempt on April 10 ... #Quebec
#
#       source  longitude  latittude lang      TE     GPE  ... LOC_FAC FAC_ORG  \
# 0  instagram -71.069230  42.356280   en  Apr-04          ...
# 1    Android -69.498244  47.917575   fr  Apr-10  Quebec  ...
#
#   ORG_FAC LOC_ORG FAC_LOC_GPE ORG_LOC_GPE LOC_FAC_GPE FAC_ORG_GPE ORG_FAC_GPE  \
# 0
# 1
#
#   LOC_ORG_GPE
# 0
# 1
#
# [2 rows x 28 columns]

# %%
df.shape
# Out:
# (17969, 28)

# %%
df.to_csv('Geocoding//data//final_posts.csv')

# %% [markdown]
# ## Extract Unique locations to Geocode

# %%
unique_GPE = df.groupby('GPE')['id'].unique()
outfilename = ('geocoding//unq_locations//GPE.csv')
unique_GPE.to_csv(outfilename)

unique_FAC = df.groupby('FAC')['id'].unique()
outfilename = ('geocoding//unq_locations//FAC.csv')
unique_FAC.to_csv(outfilename)

unique_LOC = df.groupby('LOC')['id'].unique()
outfilename = ('geocoding//unq_locations//LOC.csv')
unique_LOC.to_csv(outfilename)

unique_ORG = df.groupby('ORG')['id'].unique()
outfilename = ('geocoding//unq_locations//ORG.csv')
unique_ORG.to_csv(outfilename)

unique_FAC_GPE = df.groupby('FAC_GPE')['id'].unique()
outfilename = ('geocoding//unq_locations//FAC_GPE.csv')
unique_FAC_GPE.to_csv(outfilename)

unique_LOC_GPE = df.groupby('LOC_GPE')['id'].unique()
outfilename = ('geocoding//unq_locations//LOC_GPE.csv')
unique_LOC_GPE.to_csv(outfilename)

unique_ORG_GPE = df.groupby('ORG_GPE')['id'].unique()
outfilename = ('geocoding//unq_locations//ORG_GPE.csv')
unique_ORG_GPE.to_csv(outfilename)

unique_FAC_LOC_GPE = df.groupby('FAC_LOC_GPE')['id'].unique()
outfilename = ('geocoding//unq_locations//FAC_LOC_GPE.csv')
unique_FAC_LOC_GPE.to_csv(outfilename)

unique_FAC_ORG_GPE = df.groupby('FAC_ORG_GPE')['id'].unique()
outfilename = ('geocoding//unq_locations//FAC_ORG_GPE.csv')
unique_FAC_ORG_GPE.to_csv(outfilename)

unique_LOC_FAC_GPE = df.groupby('LOC_FAC_GPE')['id'].unique()
outfilename = ('geocoding//unq_locations//LOC_FAC_GPE.csv')
unique_LOC_FAC_GPE.to_csv(outfilename)

unique_ORG_LOC_GPE = df.groupby('ORG_LOC_GPE')['id'].unique()
outfilename = ('geocoding//unq_locations//ORG_LOC_GPE.csv')
unique_ORG_LOC_GPE.to_csv(outfilename)

unique_ORG_FAC_GPE = df.groupby('ORG_FAC_GPE')['id'].unique()
outfilename = ('geocoding//unq_locations//ORG_FAC_GPE.csv')
unique_ORG_FAC_GPE.to_csv(outfilename)

unique_LOC_ORG_GPE = df.groupby('LOC_ORG_GPE')['id'].unique()
outfilename = ('geocoding//unq_locations//LOC_ORG_GPE.csv')
unique_LOC_ORG_GPE.to_csv(outfilename)
